# %%
# Input: n = 5
# Output: 2
# Explanation: Because the 3rd row is incomplete, we return 2.

# %%
n = 5

# %%
# f(x) = a(1+r)^x

# %%
for i in range(5):
    res = 2 ** i
    print(res)
# Out:
# 1
# 2
# 4
# 8
# 16

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([3 ** i for i in range(5)])

# %%
import math
for n in range(10):
    math.sqrt(2*n+0.25)-0.5
# Out:
# 0
# 1
# 1
# 2
# 2
# 2
# 3
# 3
# 4
# 3
# 5
# 3
# 6
# 4
# 7
# 4
# 8
# 4
# 9
# 4
